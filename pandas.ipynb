# %% [markdown]
# <a href="https://colab.research.google.com/github/rkannaujia/data_science_rk/blob/data_science_basic/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## creating dataframe using list :

# %%
import pandas as pd
import numpy as np

# %%
data_list = [['Rahul', 29, 'Male'], ['Sahil', 24, 'Male'], ['Pratima', 24, 'Female']]
df_list = pd.DataFrame(data_list, columns=['Name', 'Age', 'Gender'])

display(df_list)
# Out:
#       Name  Age  Gender
# 0    Rahul   29    Male
# 1    Sahil   24    Male
# 2  Pratima   24  Female

# %% [markdown]
# ## creating dataframe using dictionary

# %%
#list
names=['Rahul', 'Sahil', 'Pratima']
ages=[29, 24, 24]
genders=['Male', 'Male', 'Female']
#creating datframe
data_dict = {'Name':names, 'Age': ages, 'Gender':genders}
df_dict = pd.DataFrame(data_dict)

display(df_dict)
# Out:
#       Name  Age  Gender
# 0    Rahul   29    Male
# 1    Sahil   24    Male
# 2  Pratima   24  Female

# %%
data_numpy = np.array([['Rahul', 29, 'Male'], ['Sahil', 24, 'Male'], ['Pratima', 24, 'Female']])
df_numpy = pd.DataFrame(data_numpy, columns=['Name', 'Age', 'Gender'])

display(df_numpy)
# Out:
#       Name Age  Gender
# 0    Rahul  29    Male
# 1    Sahil  24    Male
# 2  Pratima  24  Female

# %% [markdown]
# ## Creating dataframe using csv file

# %%
df_csv = pd.read_csv('/content/StudentsPerformances.csv')
#show first five rows in a dataframe
display(df_csv.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#show last five rows in a dataframe
display(df_csv.tail())
#getting access to the shape attribute
display(df_csv.shape)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
# (1000, 8)

# %%
#getting access to the index attribute
display(df_csv.index)
#getting acccess to the column attribute
display(df_csv.columns)
# Out:
# RangeIndex(start=0, stop=1000, step=1)
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#datatype of each column
display(df_csv.dtypes)
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#showing the info of the dataframe
display(df_csv.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %%
#describing basic statisics of the dataframe
display(df_csv.describe())
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000
